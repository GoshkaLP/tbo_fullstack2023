# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# ### Создадим новые имена столбцов

# %%
new_columns = {
    'id:': 'obj_id',
    'Название:': 'name',
    'Название (in english):': 'name_en',
    'Активный:': 'active',
    'Краткое описание:': 'description',
    'Детальное описание:': 'description_long',
    'Краткое описание (in english):': 'description_en',
    'Детальное описание (in english):': 'description_long_en',
    'МО:': 'municipal_entity',
    'Субъект федерации:': 'federal_subject',
    'Значимость:': 'significance',
    'Населённый пункт:': 'locality',
    'Населённый пункт (in english):': 'locality_en',
    'Адрес:': 'address',
    'Адрес (in english):': 'address_en',
    'ОКТМО:': 'oktmo',
    'ФЦП (федеральная целевая программа):': 'federal_targeted_program',
    'Действия с объектом:': 'object_actions',
    'Дата начала строительства / реконструкции:': 'construction_start_date',
    'Дата завершения строительства / реконструкции:': 'construction_end_date',
    'Общий объём финансирования:': 'total_funding',
    'Финансирование из федерального бюджета:': 'federal_budget_funding',
    'Финансирование из федерального бюджета (из них освоено):': 'federal_budget_funding_spent',
    'Финансирование из бюджета субъекта федерации:': 'regional_budget_funding',
    'Финансирование из бюджета субъекта федерации (из них освоено):': 'regional_budget_funding_spent',
    'Финансирование из бюджета муниципального образования:': 'local_budget_funding',
    'Финансирование из бюджета муниципального образования (из них освоено):': 'local_budget_funding_spent',
    'Финансирование из внебюджетных источников:': 'off_budget_funding',
    'Финансирование из внебюджетных источников (из них освоено):': 'off_budget_funding_spent',
    'Ключевой или нет?:': 'is_key_object',
    'Курирующий орган:': 'supervisory_authority',
    'Курирующий орган (in english):': 'supervisory_authority_en',
    'Адрес курирующего органа:': 'supervisory_authority_address',
    'Адрес курирующего органа (in english):': 'supervisory_authority_address_en',
    'Телефон курирующего органа:': 'supervisory_authority_phone',
    'Контактный телефон объекта:': 'contact_phone',
    'Режим работы Пн.-Пт.:': 'work_hours_weekdays',
    'Режим работы Сб.:': 'saturday_working_hours',
    'Режим работы Вс.:': 'sunday_working_hours',
    'Площадь:': 'area',
    'E-mail:': 'email',
    'URL сайта:': 'website_url',
    'Внесён в реестр?:': 'registered_in_registry',
    'Тип спортивного комплекса:': 'sports_complex_type',
    'Какие соревнования проводятся?:': 'competitions_held',
    'Виды спорта:': 'sports_types',
    'Яндекс координата объекта X:': 'yandex_object_coordinate_x',
    'Яндекс координата объекта Y:': 'yandex_object_coordinate_y',
    'Маштаб Яндекс-карты:': 'yandex_map_scale',
    'Яндекс координата центра X:': 'yandex_center_coordinate_x',
    'Яндекс координата центра Y:': 'yandex_center_coordinate_y',
    'Мини координата X:': 'mini_coordinate_x',
    'Мини координата Y:': 'mini_coordinate_y',
    'Генеральный план:': 'general_plan',
    'Дополнительные планы:': 'additional_plans',
    'Фото:': 'photo',
    'URL фото галереи объекта:': 'object_photo_gallery_url',
    'Видео:': 'video',
    'Панорамы:': 'panoramas',
    'Web-трансляции:': 'web_translations',
    'Прочие материалы:': 'other_materials'
}

# %% [markdown]
# ### Создание оснвовного датафрейма, из которого будут созданы производные

# %%
df1 = df.rename(columns=new_columns)

# %%
df1 = df1.dropna(subset=['name', 'yandex_object_coordinate_x', 'yandex_object_coordinate_y'])

# %%
df1['obj_id'] = df1['obj_id'].astype(int)

# %%
df1.to_csv('new_data.csv')

# %% [markdown]
# ### Создание датафрейма df_loc с основной информацией об объектах и их местоположении

# %%
df_loc = df1.loc[:, ['obj_id', 'name', 'federal_subject', 'address', 
                     'yandex_object_coordinate_x', 'yandex_object_coordinate_y']].rename(columns={'yandex_object_coordinate_x':'longitude',
                                                                                                 'yandex_object_coordinate_y':'latitude'})

# %%
df_loc
# Out:
#      obj_id                                             name  \
# 0       208      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1       214                  Спортивный зал для мини-футбола
# 2       221                            Ледовый дворец спорта
# 3       227        Спортивный центр с плавательным бассейном
# 4       234  Спортивный центр с универсальным игровым залом
# ..      ...                                              ...
# 923   28780                                 Комплексная ДЮСШ
# 924   28783                      СДЮСШОР «Динамо» по футболу
# 925   28786                          Судакская районная ДЮСШ
# 926   28794                              Гребной канал «Дон»
# 927   28803                       Гребной канал «Крылатское»
#
#          federal_subject                                            address  \
# 0    Ханты-Мансийский АО  Ханты-Мансийский автономный округ, г. Советски...
# 1    Ханты-Мансийский АО  Ханты-Мансийский автономный округ, г. Лангепас...
# ...

# %% [markdown]
# ### Создание датафрейма df_info со всей информацией об объектах

# %%
df_info = df1.drop(['name', 'name_en',
    'yandex_object_coordinate_x', 'yandex_object_coordinate_y',
                   'yandex_map_scale', 'yandex_center_coordinate_x', 'yandex_center_coordinate_y',
                   'mini_coordinate_x', 'mini_coordinate_x', 'mini_coordinate_y', 'photo', 'object_photo_gallery_url',
                   'video', 'panoramas', 'web_translations', 'other_materials',
                   'federal_budget_funding'], axis=1)

# %%
df_info['active'] = df_info['active'].replace({'Y': 1, 'N': 0})

# %%
df_info
# Out:
#      obj_id  active                                        description  \
# 0       208       1  МБОУ ДОД СДЮСШОР г. Советский единственное учр...
# 1       214       1  Отдельно стоящее здание, расположено на обособ...
# 2       221       1  Ледовый Дворец спорта в городе Сургуте открыт ...
# 3       227       1  Спортивный центр с плавательным бассейном в п....
# 4       234       1  Отдельно стоящее здание, расположено на обособ...
# ..      ...     ...                                                ...
# 923   28780       0                                                NaN
# 924   28783       0                                                NaN
# 925   28786       0                                                NaN
# 926   28794       1                                                NaN
# 927   28803       0  Гребной канал «Крылатское» — спортивное сооруж...
#
#                                       description_long  \
# 0    Общая площадь здания «Крытого плавательного ба...
# ...

# %%
df_info = df1.loc[:, ['obj_id', 'active', 'description', 'description_long', 
                         'description_en', 'description_long_en', 'municipal_entity',
                        'federal_subject', 'significance', 'locality', 'locality_en', 'address',
                        'address_en', 'sports_complex_type', 'sports_types',
                     'website_url', 'work_hours_weekdays', 'saturday_working_hours',
                         'sunday_working_hours']]

# %%
df_info['active'] = df_info['active'].replace({'Y': 1, 'N': 0}).astype(bool)

# %%
df_money = df1.loc[:, ['obj_id', 'object_actions', 'construction_start_date', 'construction_end_date',
                         'total_funding', 'federal_budget_funding', 'federal_budget_funding_spent',
                         'regional_budget_funding', 'regional_budget_funding_spent', 'local_budget_funding',
                         'regional_budget_funding_spent', 'local_budget_funding', 'local_budget_funding_spent',
                         'off_budget_funding', 'off_budget_funding_spent']]

# %%
df_supervisory = df1.loc[:, ['obj_id', 'supervisory_authority', 'supervisory_authority_phone',
                         'contact_phone', 'email', 'registered_in_registry']]

# %%
df_supervisory['registered_in_registry'] = \
df_supervisory['registered_in_registry'].replace({'Да': 1, np.nan: 0}).astype(bool)

# %%
fed_df = df_loc[['federal_subject']].drop_duplicates().reset_index().drop('index', axis=1)

# %%
fed_df['fed_id'] = range(len(fed_df))

# %%
fed_df
# Out:
#         federal_subject  fed_id
# 0   Ханты-Мансийский АО       0
# 1        Алтайский край       1
# 2    Забайкальский край       2
# 3       Камчатский край       3
# 4    Краснодарский край       4
# ..                  ...     ...
# 79    Ямало-Ненецкий АО      79
# 80          Ненецкий АО      80
# 81  Магаданская область      81
# 82          Севастополь      82
# 83      Республика Крым      83
#
# [84 rows x 2 columns]

# %%
obj_fed_df = df_loc[['obj_id', 'federal_subject']].merge(fed_df, on='federal_subject').\
drop('federal_subject', axis=1)

# %%
obj_fed_df
# Out:
#      obj_id  fed_id
# 0       208       0
# 1       214       0
# 2       221       0
# 3       227       0
# 4       234       0
# ..      ...     ...
# 922   28746      81
# 923   28778      82
# 924   28780      82
# 925   28783      83
# 926   28786      83
#
# [927 rows x 2 columns]

# %%
import folium
from folium.plugins import MarkerCluster

# %%
m = folium.Map(location=[55.77741961547338, 37.61614862414406], zoom_start=5, tiles='cartodbpositron')

# %%
marker_cluster = MarkerCluster().add_to(m)

# %%
for _, row in df_loc.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(marker_cluster)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import geopandas

# %%
gdf = geopandas.GeoDataFrame(df_loc, geometry=geopandas.points_from_xy(df_loc.longitude, df_loc.latitude))

# %%
gdf = gdf.drop(['longitude', 'latitude'], axis=1)

# %%
gdf
# Out:
#      obj_id                                             name  \
# 0       208      Крытый плавательный бассейн «Садко» СДЮСШОР
# 1       214                  Спортивный зал для мини-футбола
# 2       221                            Ледовый дворец спорта
# 3       227        Спортивный центр с плавательным бассейном
# 4       234  Спортивный центр с универсальным игровым залом
# ..      ...                                              ...
# 923   28780                                 Комплексная ДЮСШ
# 924   28783                      СДЮСШОР «Динамо» по футболу
# 925   28786                          Судакская районная ДЮСШ
# 926   28794                              Гребной канал «Дон»
# 927   28803                       Гребной канал «Крылатское»
#
#          federal_subject                                            address  \
# 0    Ханты-Мансийский АО  Ханты-Мансийский автономный округ, г. Советски...
# 1    Ханты-Мансийский АО  Ханты-Мансийский автономный округ, г. Лангепас...
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://tbo_admin:056Lr3RCHY9aM0lm@gmrybkin.com:5432/tbo_db")

# %%
gdf.to_postgis("LocationsGeometry", con=engine, if_exists='replace')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/io/sql.py:400: UserWarning: Could not parse CRS from the GeoDataFrame. Inserting data without defined CRS.
#   srid = _get_srid_from_crs(gdf)

# %%
df_info.to_sql('LocationsInfo', con=engine, if_exists='replace', index=False)
# Out:
# 927

# %%
obj_fed_df.to_sql('LocationsFederals', con=engine, if_exists='replace', index=False)
# Out:
# 927

# %%
fed_df.to_sql('Federals', con=engine, if_exists='replace', index=False)
# Out:
# 84

# %%
df_supervisory.to_sql('LocationsSupervisory', con=engine, if_exists='replace', index=False)
# Out:
# 927

# %%
df_money.to_sql('LocationsSpending', con=engine, if_exists='replace', index=False)
# Out:
# 927
